# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from proct_olis.datalake.sellers.model import Transformation 

transformation = Transformation()

# %%
transformation.read()

# %%
transformation.transformation()

# %%
transformation.final_df.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ product_i ┆ product_c ┆ product_n ┆ product_d ┆ … ┆ product_w ┆ product_l ┆ product_h ┆ product_ │
# │ d         ┆ ategory_n ┆ ame_lengh ┆ escriptio ┆   ┆ eight_g   ┆ ength_cm  ┆ eight_cm  ┆ width_cm │
# │ ---       ┆ ame       ┆ t         ┆ n_lenght  ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ i64       ┆ i64       ┆ i64      │
# │           ┆ str       ┆ i64       ┆ i64       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1e9e8ef04 ┆ perfumari ┆ 40        ┆ 287       ┆ … ┆ 225       ┆ 16        ┆ 10        ┆ 14       │
# │ dbcff4541 ┆ a         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
transformation.write()
