# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from proct_olis.operations.order_status_type.model import Transformation 

transformation = Transformation()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from proct_olis.operations.order_status_type.model import Transformation
# ----> 3 transformation = Transformation()
#
# File <string>:8, in __init__(self, entity_map, final_df, config, settings, process_name)
#
# File /workspace/proct_olis/core/__init__.py:29, in TransformationBase.__post_init__(self)
#      26 if not self.config:
#      27     self.config = Config.load_config(Path(inspect.getfile(self.__class__)).with_name("config.yml").as_posix())
# ---> 29 self.reader = Reader(self.process_name, self.config, self.settings)
#      30 self.utilities = Utilities()
#      31 self.pre_transformation()
#
# File <string>:7, in __init__(self, process_name, config, settings, source_dataframes)
#
# File /workspace/proct_olis/core/reader.py:100, in Reader.__post_init__(self)
# ...

# %%
transformation.read()

# %%
transformation.transformation()

# %%
transformation.final_df.head(20)

# %%
transformation.write()
